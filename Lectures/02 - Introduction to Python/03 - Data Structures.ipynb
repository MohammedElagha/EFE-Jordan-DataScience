# %% [markdown]
# # List

# %% [markdown]
# **List** is ordered, changable, allowing to duplicate; *list* of items

# %% [markdown]
# ##### Declaration

# %%
l = ['a', 'b', 55, True]
l
# Out:
# ['a', 'b', 55, True]

# %%
l2 = list(('a', 'b', 55, True))
l2
# Out:
# ['a', 'b', 55, True]

# %%
type(l)
# Out:
# list

# %% [markdown]
# ##### Length/Size

# %%
len(l)
# Out:
# 4

# %% [markdown]
# ##### Some Functions

# %%
l.append(56)
l
# Out:
# ['a', 'b', 55, True, 56]

# %%
l.remove('a')
l
# Out:
# ['b', 55, True, 56]

# %%
l.clear()
l
# Out:
# []

# %% [markdown]
# ---

# %% [markdown]
# # Set

# %% [markdown]
# **Set** is unordered, unchangable, preventing from duplicate; *bag* of items

# %%
thisset = {"apple", "banana", "cherry"}
thisset
# Out:
# {'apple', 'banana', 'cherry'}

# %%
thisset = {"apple", "banana", "cherry", "apple"}
thisset
# Out:
# {'apple', 'banana', 'cherry'}

# %%
thisset.add('strawberry')
thisset
# Out:
# {'apple', 'banana', 'cherry', 'strawberry'}

# %%
thisset.remove('strawberry')
thisset
# Out:
# {'apple', 'banana', 'cherry'}

# %% [markdown]
# ---

# %% [markdown]
# # Tuple

# %% [markdown]
# **Tuple** is ordered, unchangable, allowing from duplicate; *object* of items

# %%
t = ('Hi', 'Hello')
t
# Out:
# ('Hi', 'Hello')

# %%
t1, t2 = ('Hi', 'Hello')
print(t1)
print(t2)
# Out:
# Hi
# Hello

# %% [markdown]
# ---

# %% [markdown]
# # Dictionary

# %% [markdown]
# **Dictionary** is unordered, changable, preventing from duplicate; *set* of items

# %%
d1 = {'name': 'Ali', 'age': 25, 'address': 'Amman'}
d1
# Out:
# {'address': 'Amman', 'age': 25, 'name': 'Ali'}

# %%
d2 = {'name': 'Ali', 'age': 25, 'address': 'Amman', 'courses': ['JAVA', 'DS', 'PHP']}
d2
# Out:
# {'address': 'Amman',
#  'age': 25,
#  'courses': ['JAVA', 'DS', 'PHP'],
#  'name': 'Ali'}
