# %% [markdown]
# # Indexing

# %% [markdown]
# ##### List

# %%
l = ['Ali', 'Hosam', 'Sarah', 'Jo']
l
# Out:
# ['Ali', 'Hosam', 'Sarah', 'Jo']

# %%
l[0]
# Out:
# 'Ali'

# %%
l[len(l)-1]
# Out:
# 'Jo'

# %% [markdown]
# ##### Set

# %%
s = {'Ali', 'Hosam', 'Sarah', 'Jo'}
s
# Out:
# {'Ali', 'Hosam', 'Jo', 'Sarah'}

# %%
s.pop()
# Out:
# 'Hosam'

# %%
s.pop()
# Out:
# 'Ali'

# %%
s.pop()
# Out:
# 'Sarah'

# %%
s.pop()
# Out:
# 'Jo'

# %%
s.pop()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-c88c8c48122b> in <module>()
# ----> 1 s.pop()
#
# KeyError: 'pop from an empty set'

# %% [markdown]
# ##### Tuple

# %%
t = ('Hi', 'Hello')

# %%
t[0]
# Out:
# 'Hi'

# %%
t[len(t)-1]
# Out:
# 'Hello'

# %%
t1, t2 = ('Hi', 'Hello')
print(t1)
print(t2)
# Out:
# Hi
# Hello

# %% [markdown]
# ##### Dictionary

# %%
d = {'name': 'Ali', 'age': 25, 'address': 'Amman', 'courses': ['JAVA', 'DS', 'PHP']}
d
# Out:
# {'address': 'Amman',
#  'age': 25,
#  'courses': ['JAVA', 'DS', 'PHP'],
#  'name': 'Ali'}

# %%
d['name']
# Out:
# 'Ali'

# %%
d['courses']
# Out:
# ['JAVA', 'DS', 'PHP']

# %%
d['courses'][0]
# Out:
# 'JAVA'

# %% [markdown]
# ---

# %% [markdown]
# # Range Indexing

# %%
nl = ['a', 'b', 'c', 'd', 'f']

# %%
nl[0:2]
# Out:
# ['a', 'b']

# %%
nl[:2]
# Out:
# ['a', 'b']

# %%
nl[0:1]
# Out:
# ['a']

# %%
nl[:1]
# Out:
# ['a']

# %%
nl[1:3]
# Out:
# ['b', 'c']

# %%
nl[1:4]
# Out:
# ['b', 'c', 'd']

# %%
nl[1:5]
# Out:
# ['b', 'c', 'd', 'f']

# %%
nl[1:]
# Out:
# ['b', 'c', 'd', 'f']

# %%
nl[1:-1]
# Out:
# ['b', 'c', 'd']

# %%
nl[-4:-1]
# Out:
# ['b', 'c', 'd']

# %% [markdown]
# ---

# %% [markdown]
# # String Indexing

# %%
str_val = 'Hello world. I am here'

# %%
str_val[0]
# Out:
# 'H'

# %%
str_val[len(str_val)-1]
# Out:
# 'e'

# %%
str_val[0:14]
# Out:
# 'Hello world. I'
